# %% [markdown]
# # 👋 Hello from the Modelbit team!
#
# Thanks for downloading our notebook! We hope it helps you on your journey to build and deploy a lead scorer.
#
# For more assistance, or just to say hi, reach out: harry@modelbit.com.

# %% [markdown]
# ## 1. Get the leads

# %%
#if you get the invalid ssl url certificate else move on to the next line of code
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
import pandas 

leads = pandas.read_csv(
    "https://cdn.modelbit.com/blog/2022-09-30-how-to-build-and-deploy-a-lead-scorer/fake_leads.csv",
    index_col = 0
)

leads
# Out:
#          lead_source num_employees          industry  converted_to_customer
# 0           facebook      501-1000             Other                  False
# 1        direct-mail         11-50             Other                  False
# 2                NaN           NaN               NaN                   True
# 3        direct-mail          1-10             Other                   True
# 4                NaN        51-100               NaN                   True
# ...              ...           ...               ...                    ...
# 49995          other         11-50            Retail                   True
# 49996  search-engine         11-50             Legal                  False
# 49997        twitter        51-100   Food & Beverage                   True
# 49998  search-engine          1-10  Marketing Agency                  False
# 49999       facebook       101-250        Healthcare                   True
#
# [50000 rows x 4 columns]

# %% [markdown]
# ## 2. Feature engineering

# %%
X = leads[["lead_source", "industry"]]

def convert_num_employees(num_employees: str) -> int:
    num_employees_map = {
        '1-10':     1,
        '11-50':    2,
        '51-100':   3,
        '101-250':  4,
        '251-500':  5,
        '501-1000': 6,
        '1000+':    7
    }
    
    if num_employees in num_employees_map:
        return num_employees_map[num_employees]
    
    return 0

X = X.assign(num_employees_feature = leads['num_employees'].apply(convert_num_employees))
X
# Out:
#          lead_source          industry  num_employees_feature
# 0           facebook             Other                      6
# 1        direct-mail             Other                      2
# 2                NaN               NaN                      0
# 3        direct-mail             Other                      1
# 4                NaN               NaN                      3
# ...              ...               ...                    ...
# 49995          other            Retail                      2
# 49996  search-engine             Legal                      2
# 49997        twitter   Food & Beverage                      3
# 49998  search-engine  Marketing Agency                      1
# 49999       facebook        Healthcare                      4
#
# [50000 rows x 3 columns]

# %%
y = leads['converted_to_customer'].astype(int)
y
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 49995    1
# 49996    0
# 49997    1
# 49998    0
# 49999    1
# Name: converted_to_customer, Length: 50000, dtype: int64

# %% [markdown]
# ## 3. Fitting the model

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from xgboost import XGBRegressor

pipeline = Pipeline([
    ('encoder', OneHotEncoder(handle_unknown = 'ignore')),
    ('regression', XGBRegressor())
])

pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('encoder', OneHotEncoder(handle_unknown='ignore')),
#                 ('regression',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None, early_stopping_rounds=None,
#                               enable_categorical=False, eval_metric=None,
#                               feature_types=None, gamma=None, gpu_id=None,
#                               grow_policy=None, importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=None, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, n_estimators=100,
#                               n_jobs=None, num_parallel_tree=None,
#                               predictor=None, random_state=None, ...))])

# %% [markdown]
# ## 4. Building the function to deploy

# %%
def score_lead(lead_source: str, industry: str, num_employees: str) -> float:
    num_employees_feature = convert_num_employees(num_employees)
    df = pandas.DataFrame({
        'lead_source': [lead_source],
        'industry': [industry],
        'num_employees_feature': [num_employees_feature]
    })
    
    return float(pipeline.predict(df)[0])

score_lead('facebook', 'Entertainment', '11-50')
# Out:
# 0.7944052815437317

# %% [markdown]
# ## 5. Deploy! 🚀

# %%
import modelbit
mb = modelbit.login()
mb.deploy(score_lead)
# Out:
# <div style="margin: 0; padding: 5px; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#   <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; font-weight: bold; color: green;">Connect to Modelbit</div>
#   <div style="margin: 0 0 20px 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#     Open <a style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; color: #106ba3; text-decoration: none; cursor: pointer;" href="https://app.modelbit.com/t/eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1dWlkIjoiODI2MGZiOWNjZWRhNDQyNyIsImtpbmQiOiJub3RlYm9vayIsImlhdCI6MTY3NjMwODI0NywiZXhwIjoxNjc2MzUxNDQ3fQ.lduC3gWTS4Cbz7cvAOsJnNFe_ijU-3DYw-AJzsWRkUA?source=notebook" target="_blank">modelbit.com/t/eyJhbGciOi...</a> to authenticate this kernel.
#     <a style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; color: #106ba3; text-decoration: none; cursor: pointer;" href="https://doc.modelbit.com/" target="_blank">Learn more.</a>
#   </div>
#
# </div>
# <div style="margin: 0; padding: 5px; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#   <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; font-weight: bold; color: #714488;">
#     Preparing <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; background-color: #f3f4f6;">score_lead</span>...
#   </div>
# </div>
# Warning, skipping module '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/DQ-0.1.0-py3.9.egg': [Errno 20] Not a directory: '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/DQ-0.1.0-py3.9.egg'
# <div style="margin: 0; padding: 5px; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#   <span style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; color: #E2548A; font-weight: bold;">Error:</span>
#   Unable to deploy.
# </div>
# Warning, skipping module '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/DQ-0.1.0-py3.9.egg': [Errno 20] Not a directory: '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/DQ-0.1.0-py3.9.egg'
# Warning, skipping module '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/DQ-0.1.0-py3.9.egg': [Errno 20] Not a directory: '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/DQ-0.1.0-py3.9.egg'
# <div style="margin: 0; padding: 5px; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#   <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; font-weight: bold; color: #714488;">
#     Deployment <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; background-color: #f3f4f6;">score_lead</span>:
#
#       <span style="">Not Ready to Deploy</span>
#
#   </div>
#
#
#
#
#   <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; margin-top: 10px;">
#     <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; font-weight: bold; color: #714488;">Heads up!</div>
#     <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;" id="fst-mb-751980170">
#       <div style="margin: 0; padding: 5px; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; border-left: 1px solid #714488; margin-bottom: 10px;">
#
#
#
#
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#         Your deployment imports <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; background-color: #f3f4f6;">xgboost.sklearn</span> but you did not
#         specify <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; background-color: #f3f4f6;">xgboost==1.7.3</span> in your production environment.
#       </div>
#
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">To add the missing package to your production environment, run:</div>
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; padding-left: 15px;">
#         <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; background-color: #f3f4f6;">mb.deploy(my_deploy_function, <b>python_packages=["xgboost==1.7.3"]</b>)</span>
#       </div>
#
#
#
#
#   </div>
#     </div>
#
#
#         <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;" id="btn-mb-751980170">
#           There are 3 more inconsistencies.
#           <span style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; color: #106ba3; text-decoration: none; cursor: pointer;" onClick="document.getElementById('lst-mb-751980170').style.display='block'; document.getElementById('btn-mb-751980170').style.display='none'; document.getElementById('fst-mb-751980170').style.display='none';">
#             View all.
#           </span>
#         </div>
#
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; display: none;" id="lst-mb-751980170">
#
#           <div style="margin: 0; padding: 5px; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; border-left: 1px solid #714488; margin-bottom: 10px;">
#
#
#
#
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#         Your deployment imports <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; background-color: #f3f4f6;">xgboost.sklearn</span> but you did not
#         specify <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; background-color: #f3f4f6;">xgboost==1.7.3</span> in your production environment.
#       </div>
#
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">To add the missing package to your production environment, run:</div>
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; padding-left: 15px;">
#         <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; background-color: #f3f4f6;">mb.deploy(my_deploy_function, <b>python_packages=["xgboost==1.7.3"]</b>)</span>
#       </div>
#
#
#
#
#   </div>
#
#           <div style="margin: 0; padding: 5px; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; border-left: 1px solid #714488; margin-bottom: 10px;">
#
#
#
#
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#         Your deployment imports <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; background-color: #f3f4f6;">sklearn.pipeline</span> but you did not
#         specify <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; background-color: #f3f4f6;">scikit-learn==1.0.2</span> in your production environment.
#       </div>
#
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">To add the missing package to your production environment, run:</div>
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; padding-left: 15px;">
#         <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; background-color: #f3f4f6;">mb.deploy(my_deploy_function, <b>python_packages=["scikit-learn==1.0.2"]</b>)</span>
#       </div>
#
#
#
#
#   </div>
#
#           <div style="margin: 0; padding: 5px; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; border-left: 1px solid #714488; margin-bottom: 10px;">
#
#
#
#
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#         Your deployment imports <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; background-color: #f3f4f6;">sklearn.preprocessing._encoders</span> but you did not
#         specify <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; background-color: #f3f4f6;">scikit-learn==1.0.2</span> in your production environment.
#       </div>
#
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">To add the missing package to your production environment, run:</div>
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; padding-left: 15px;">
#         <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; background-color: #f3f4f6;">mb.deploy(my_deploy_function, <b>python_packages=["scikit-learn==1.0.2"]</b>)</span>
#       </div>
#
#
#
#
#   </div>
#
#           <div style="margin: 0; padding: 5px; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; border-left: 1px solid #714488; margin-bottom: 10px;">
#
#
#
#
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#         Your deployment imports <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; background-color: #f3f4f6;">pandas</span> but you did not
#         specify <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; background-color: #f3f4f6;">pandas==1.3.5</span> in your production environment.
#       </div>
#
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">To add the missing package to your production environment, run:</div>
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; padding-left: 15px;">
#         <span style="margin: 0; padding: 3px; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; background-color: #f3f4f6;">mb.deploy(my_deploy_function, <b>python_packages=["pandas==1.3.5"]</b>)</span>
#       </div>
#
#
#
#
#   </div>
#
#       </div>
#
#   </div>
#
#
#
#
#   <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; margin-top: 10px;">
#     <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; font-weight: bold; color: #E2548A;">Errors</div>
#
#       <div style="margin: 0; padding: 5px; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; border-left: 1px solid #714488; margin-bottom: 10px;">
#
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#         You are not logged in to Modelbit. Please log in, then deploy.
#       </div>
#
#   </div>
#
#   </div>
#
#
#
#
#   <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; margin-top: 10px;">
#     <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; font-weight: bold; color: green;">Tips</div>
#
#       <div style="margin: 0; padding: 5px; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; border-left: 1px solid #714488; margin-bottom: 10px;">
#
#       <div style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#         Add unit tests to improve this deployment. <a style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; color: #106ba3; text-decoration: none; cursor: pointer;" href="https://doc.modelbit.com/#/deployments/unit-tests" target="_blank">Learn more.</a>
#       </div>
#
#   </div>
#
#   </div>
#
#
#
#     <table style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#   <thead style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#
#       <th style="margin: 0; padding: 10px; line-height: 1; font-size: 14px; vertical-align: middle; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; text-align: left; font-weight: bold;">Property</th>
#
#       <th style="margin: 0; padding: 10px; line-height: 1; font-size: 14px; vertical-align: middle; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; text-align: left; font-weight: bold;">Value</th>
#
#   </thead>
#   <tbody style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;">
#
#       <tr style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; ">
#
#           <td style="margin: 0; padding: 10px; line-height: 1; font-size: 14px; vertical-align: middle; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; text-align: left;">
#
#
#                 Function
#
#
#           </td>
#
#           <td style="margin: 0; padding: 10px; line-height: 1; font-size: 14px; vertical-align: middle; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; text-align: left;">
#
#
#                 <span style="margin: 0; padding: 0; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; white-space: pre-wrap;">score_lead(lead_source, industry, num_employees)</span>
#
#
#           </td>
#
#       </tr>
#
#       <tr style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;  background-color: #f3f4f6; ">
#
#           <td style="margin: 0; padding: 10px; line-height: 1; font-size: 14px; vertical-align: middle; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; text-align: left;">
#
#
#                 Helpers
#
#
#           </td>
#
#           <td style="margin: 0; padding: 10px; line-height: 1; font-size: 14px; vertical-align: middle; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; text-align: left;">
#
#
#                 <span style="margin: 0; padding: 0; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; white-space: pre-wrap;">convert_num_employees(num_employees, num_employees_map)</span>
#
#
#           </td>
#
#       </tr>
#
#       <tr style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; ">
#
#           <td style="margin: 0; padding: 10px; line-height: 1; font-size: 14px; vertical-align: middle; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; text-align: left;">
#
#
#                 Values
#
#
#           </td>
#
#           <td style="margin: 0; padding: 10px; line-height: 1; font-size: 14px; vertical-align: middle; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; text-align: left;">
#
#
#                 <span style="margin: 0; padding: 0; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; white-space: pre-wrap;">pipeline: Pipeline(steps=[(&#39;encoder&#39;, OneHotEncoder(handle_unknown=&#39;ignore&#39;)), (&#39;regression&#39;, XGBRegressor(base_score=None, booster=None, callbacks=None, colsample_bylevel=None, colsample_bynode=None, colsample...</span>
#
#
#           </td>
#
#       </tr>
#
#       <tr style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none;  background-color: #f3f4f6; ">
#
#           <td style="margin: 0; padding: 10px; line-height: 1; font-size: 14px; vertical-align: middle; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; text-align: left;">
#
#
#                 Imports
#
#
#           </td>
#
#           <td style="margin: 0; padding: 10px; line-height: 1; font-size: 14px; vertical-align: middle; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; text-align: left;">
#
#
#                 <span style="margin: 0; padding: 0; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; white-space: pre-wrap;">from typing import *
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing._encoders import OneHotEncoder
# from xgboost.sklearn import XGBRegressor
# import pandas as pandas</span>
#
#
#           </td>
#
#       </tr>
#
#       <tr style="margin: 0; padding: 0; line-height: 1.75; font-size: 14px; vertical-align: baseline; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; ">
#
#           <td style="margin: 0; padding: 10px; line-height: 1; font-size: 14px; vertical-align: middle; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; text-align: left;">
#
#
#                 Python Version
#
#
#           </td>
#
#           <td style="margin: 0; padding: 10px; line-height: 1; font-size: 14px; vertical-align: middle; list-style: none; font-family: Roboto, Arial, sans-serif; background: none; text-align: left;">
#
#
#                 <span style="margin: 0; padding: 0; line-height: 1.75; font-size: 13px; vertical-align: baseline; list-style: none; font-family: monospace; background: none; color: #714488; font-weight: 400; white-space: pre-wrap;">3.9</span>
#
#
#           </td>
#
#       </tr>
#
#   </tbody>
# </table>
#
#
#
# </div>
